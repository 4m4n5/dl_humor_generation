# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
import shutil
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
base_url = "https://memegenerator.net/memes/popular/alltime/page/"

columns = ['Title', 'Link', 'Image']
data = DataFrame(columns=columns)

for page in range(1, 201):
    if page % 20 == 0:
        print(page)
    url = base_url + str(page)
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    img_divs = soup.findAll('div', {'class': 'char-img'})
    for img_div in img_divs:
        img_src = img_div.find('img').get('src')
        link = img_div.find('a').get('href')
        title = img_div.find('div', {'class': 'left'}).text.strip()
        tmp = DataFrame([[title, link, img_src]])
        tmp.columns = columns
        data = data.append(tmp, ignore_index=True)

# %%
data.to_csv('../data/meme_metadata.csv', encoding='utf-8', index=False)

# %%
data = pd.read_csv('../data/meme_metadata.csv')

# %%
# EDIT THESE NUMBERS DEPENDING ON THE MEMES YOU ARE SUPPOSED TO CRAWL
offset = 100
start = 0 + 60 + offset
end = start + 10
data = data[start:end]

# %%
def download_web_image(url, name):
    r = requests.get(url, stream=True, headers={'User-agent': 'Mozilla/5.0'})
    full_name = '../data/images' + str(name) + '.jpg'
    
    if r.status_code == 200:
        with open(full_name, 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
    else:
        print('Could not download ' + str(name))
    return full_name

# %%
columns = ['Title', 'Link', 'CaptionTop', 'CaptionBottom', 'ImageName', 'Upvotes']
caption_data = DataFrame(columns=columns)

for index, row in data.iterrows():
    if index % 500 == 0:
        print(index)
    meme_link = row['Link']
    img_link = row['Image']
    img_name = row['Title']
    download_name = download_web_image(img_link, meme_link)
    base_url = 'https://memegenerator.net'
    page = 1
    flag = True
    for page in range(1, 500):
        url = base_url + row['Link'] + '/images/popular/alltime/page/' + str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        for meme in soup.findAll('div', {'class': 'gallery-img'}):
            caption = meme.find('div', {'class': 'optimized-instance-container'})
            text0 = caption.find('div', {'class': 'optimized-instance-text0'}).text.strip()
            text1 = caption.find('div', {'class': 'optimized-instance-text1'}).text.strip()
            upvotes = int(meme.find('div', {'class': 'score'}).text.replace(',', '').strip())
            if upvotes < 0:
                continue
            tmp = DataFrame([[img_name, meme_link, text0, text1, download_name, upvotes]])
            tmp.columns = columns
            caption_data = caption_data.append(tmp, ignore_index=True)

# %%
caption_data.to_csv('../data/caption_data_' + str(start) + '_' + str(end) + '.csv', encoding='utf-8', index=False)

# %%
caption_data
# Out:
#                 Title            Link  \
# 0           green fan      /Green-Fan
# 1           green fan      /Green-Fan
# 2           green fan      /Green-Fan
# 3           green fan      /Green-Fan
# 4           green fan      /Green-Fan
# 5           green fan      /Green-Fan
# 6           green fan      /Green-Fan
# 7           green fan      /Green-Fan
# 8           green fan      /Green-Fan
# 9           green fan      /Green-Fan
# 10          green fan      /Green-Fan
# 11          green fan      /Green-Fan
# 12          green fan      /Green-Fan
# 13          green fan      /Green-Fan
# 14          green fan      /Green-Fan
# 15          green fan      /Green-Fan
# 16          green fan      /Green-Fan
# 17          green fan      /Green-Fan
# 18          green fan      /Green-Fan
# 19          green fan      /Green-Fan
# 20          green fan      /Green-Fan
# 21          green fan      /Green-Fan
# 22          green fan      /Green-Fan
# 23          green fan      /Green-Fan
# 24          green fan      /Green-Fan
# 25          green fan      /Green-Fan
# 26          green fan      /Green-Fan
# 27          green fan      /Green-Fan
# 28          green fan      /Green-Fan
# 29          green fan      /Green-Fan
# ...               ...             ...
# 235949  ButtHurt Sean  /Butthurt-Sean
# 235950  ButtHurt Sean  /Butthurt-Sean
# 235951  ButtHurt Sean  /Butthurt-Sean
# 235952  ButtHurt Sean  /Butthurt-Sean
# 235953  ButtHurt Sean  /Butthurt-Sean
# 235954  ButtHurt Sean  /Butthurt-Sean
# 235955  ButtHurt Sean  /Butthurt-Sean
# 235956  ButtHurt Sean  /Butthurt-Sean
# 235957  ButtHurt Sean  /Butthurt-Sean
# 235958  ButtHurt Sean  /Butthurt-Sean
# 235959  ButtHurt Sean  /Butthurt-Sean
# 235960  ButtHurt Sean  /Butthurt-Sean
# 235961  ButtHurt Sean  /Butthurt-Sean
# 235962  ButtHurt Sean  /Butthurt-Sean
# 235963  ButtHurt Sean  /Butthurt-Sean
# 235964  ButtHurt Sean  /Butthurt-Sean
# 235965  ButtHurt Sean  /Butthurt-Sean
# 235966  ButtHurt Sean  /Butthurt-Sean
# 235967  ButtHurt Sean  /Butthurt-Sean
# 235968  ButtHurt Sean  /Butthurt-Sean
# 235969  ButtHurt Sean  /Butthurt-Sean
# 235970  ButtHurt Sean  /Butthurt-Sean
# 235971  ButtHurt Sean  /Butthurt-Sean
# 235972  ButtHurt Sean  /Butthurt-Sean
# 235973  ButtHurt Sean  /Butthurt-Sean
# 235974  ButtHurt Sean  /Butthurt-Sean
# 235975  ButtHurt Sean  /Butthurt-Sean
# 235976  ButtHurt Sean  /Butthurt-Sean
# 235977  ButtHurt Sean  /Butthurt-Sean
# 235978  ButtHurt Sean  /Butthurt-Sean
#
#                                                CaptionTop  \
# 0                                                       y
# 1                                      город моей мечты -
# 2                                    NOT A GREEN DAY FAN?
# 3       пять букв. слово, которое занимает все мои мыс...
# 4                               Hahaha I'm good and you??
# 5                    YOU LISTEN TO OLD GREEN DAY? DOOKIE?
# 6                                           I know right?
# 7                        Главный минус моего парня в том,
# 8                                     MI NOMBRE ES ELENIE
# 9                                                  We are
# 10                                                 I love
# 11                Why Green Day are not coming to my town
# 12                                     My official page -
# 13           I bought a magazine with a poster Green Day.
# 14                 Found a fan of Green Day from my city.
# 15      Мама: ну зачем тебе эти конверсы? Давай обычны...
# 16                                             ONE MINUTE
# 17                               Я, конечно, не идеальна,
# 18                               Я, конечно, не идеальна,
# 19                               Я, конечно, не идеальна,
# 20           Спонсор моей бессоницы - Green day в голове.
# 21                                                 я хочу
# 22                             Зачем ходить по магазинам,
# 23                                           делаю уроки.
# 24                               я сижу на зелёной диете.
# 25                                                 I LOVE
# 26                             wants to be an acccountant
# 27                    Любимое число на английском языке -
# 28                                                 HAHAHA
# 29                                have you seen my pussy?
# ...                                                   ...
# 235949                                      She is hot...
# 235950                                      She is hot...
# 235951                                      She is hot...
# 235952                                      She is hot...
# 235953                                      She is hot...
# 235954                                      She is hot...
# 235955                                      She is hot...
# 235956                                      She is hot...
# 235957                                      She is hot...
# 235958                                      She is hot...
# 235959                                      She is hot...
# 235960                                      She is hot...
# 235961                                      She is hot...
# 235962                                      She is hot...
# 235963                                        Stop saying
# 235964                                            Brittni
# 235965                                          Seaaaaaan
# 235966          nobody must know that I was never invited
# 235967                                            Felicia
# 235968                                            Felicia
# 235969                                            Brittni
# 235970                                           yall got
# 235971                                   i pee on comupte
# 235972                                  peepee on compuer
# 235973                                i peepee on compute
# 235974                                married 2 hours ago
# 235975       When your son want to be like george micheal
# 235976
# 235977  Propaganda Islamista / Musulmana Terrorista, E...
# 235978  ISIS Islamic State (ISIL / IS) Daesh Terrorist...
#
#                                             CaptionBottom  \
# 0                                                    know
# 1                                                Гринсити
# 2           BITCH PLEASE, I KNOW LIKE 3 SONGS FROM DOOKIE
# 3                                                Грины!!!
# 4
# 5                            BITCH I LISTEN TO 39/SMOOTH!
# 6                          But seriously I'm freaking out
# 7       что он живёт в оклэнде. и вообще, он воображае...
# 8                                 Y ME GUSTA REIRME SOLA.
# 9                                         american idiots
# 10                                              green day
# 11                                       with a concert?!
# 12                                  http://vk.com/t_green
# 13                          Hung the poster in the frame.
# 14                  My life will never be the same again!
# 15                               Я: мам, ты издеваешься?!
# 16                                         SMASHES GUITAR
# 17                                  но и ты не билли джо!
# 18                                 но и ты не майк дёрнт!
# 19                                    но и ты не тре кул!
# 20                   green day в голове - всегда со мной!
# 21                                   на концерт green day
# 22              если там всё равно нет мерча с green day?
# 23                           параллельно переслушиваю UNO
# 24      нет, я не ем зелёные овощи, я бешусь под green...
# 25                                                  GREEN
# 26                             fails every accounting sac
# 27                                                billion
# 28                                           GRAPPIG MAN.
# 29                            it looks like a sad grandma
# ...                                                   ...
# 235949                            ...But so are my sheets
# 235950                            ...But so are my sheets
# 235951                            ...But so are my sheets
# 235952                            ...But so are my sheets
# 235953                            ...But so are my sheets
# 235954                            ...But so are my sheets
# 235955                            ...But so are my sheets
# 235956                            ...But so are my sheets
# 235957                            ...But so are my sheets
# 235958                            ...But so are my sheets
# 235959                            ...But so are my sheets
# 235960                            ...But so are my sheets
# 235961                            ...But so are my sheets
# 235962                            ...But so are my sheets
# 235963                    she is hot but so are my sheets
# 235964                                       COME LOVE ME
# 235965                           Steek je hand in je reet
# 235966                                      so just smile
# 235967                 Loves being hate fucked in the ass
# 235968              Loves the softness of Martin's carrot
# 235969                                 sucks alot of dick
# 235970                                       any laptops?
# 235971  bzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbz...
# 235972                                       bzbzbzbzbzbz
# 235973  bzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbzbz...
# 235974                               cheated 3 hours ago!
# 235975
# 235976                                      ok fair point
# 235977                         Los garífunas de Guatemala
