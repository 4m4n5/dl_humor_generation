# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
import shutil
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
base_url = "https://memegenerator.net/memes/popular/alltime/page/"

columns = ['Title', 'Link', 'Image']
data = DataFrame(columns=columns)

for page in range(1, 201):
    if page % 20 == 0:
        print(page)
    url = base_url + str(page)
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    img_divs = soup.findAll('div', {'class': 'char-img'})
    for img_div in img_divs:
        img_src = img_div.find('img').get('src')
        link = img_div.find('a').get('href')
        title = img_div.find('div', {'class': 'left'}).text.strip()
        tmp = DataFrame([[title, link, img_src]])
        tmp.columns = columns
        data = data.append(tmp, ignore_index=True)

# %%
data.to_csv('../data/meme_metadata.csv', encoding='utf-8', index=False)

# %%
data = pd.read_csv('../data/meme_metadata.csv')

# %%
# EDIT THESE NUMBERS DEPENDING ON THE MEMES YOU ARE SUPPOSED TO CRAWL
offset = 100
start = 0 + 50 + offset
end = start + 10
data = data[start:end]

# %%
def download_web_image(url, name):
    r = requests.get(url, stream=True, headers={'User-agent': 'Mozilla/5.0'})
    full_name = '../data/images' + str(name) + '.jpg'
    
    if r.status_code == 200:
        with open(full_name, 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
    else:
        print('Could not download ' + str(name))
    return full_name

# %%
columns = ['Title', 'Link', 'CaptionTop', 'CaptionBottom', 'ImageName', 'Upvotes']
caption_data = DataFrame(columns=columns)

for index, row in data.iterrows():
    if index % 500 == 0:
        print(index)
    meme_link = row['Link']
    img_link = row['Image']
    img_name = row['Title']
    download_name = download_web_image(img_link, meme_link)
    base_url = 'https://memegenerator.net'
    page = 1
    flag = True
    for page in range(1, 500):
        url = base_url + row['Link'] + '/images/popular/alltime/page/' + str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        for meme in soup.findAll('div', {'class': 'gallery-img'}):
            caption = meme.find('div', {'class': 'optimized-instance-container'})
            text0 = caption.find('div', {'class': 'optimized-instance-text0'}).text.strip()
            text1 = caption.find('div', {'class': 'optimized-instance-text1'}).text.strip()
            upvotes = int(meme.find('div', {'class': 'score'}).text.replace(',', '').strip())
            if upvotes < 0:
                continue
            tmp = DataFrame([[img_name, meme_link, text0, text1, download_name, upvotes]])
            tmp.columns = columns
            caption_data = caption_data.append(tmp, ignore_index=True)

# %%
caption_data.to_csv('../data/caption_data_' + str(start) + '_' + str(end) + '.csv', encoding='utf-8', index=False)

# %%
caption_data
# Out:
#                         Title                    Link  \
# 0       Stereotypical Redneck  /Stereotypical-Redneck
# 1       Stereotypical Redneck  /Stereotypical-Redneck
# 2       Stereotypical Redneck  /Stereotypical-Redneck
# 3       Stereotypical Redneck  /Stereotypical-Redneck
# 4       Stereotypical Redneck  /Stereotypical-Redneck
# 5       Stereotypical Redneck  /Stereotypical-Redneck
# 6       Stereotypical Redneck  /Stereotypical-Redneck
# 7       Stereotypical Redneck  /Stereotypical-Redneck
# 8       Stereotypical Redneck  /Stereotypical-Redneck
# 24                                             my and dad
# 25                            my beers smarter than yours
# 26                                       refers to dog as
# 27                                           bought a 6.0
# 28                       I'll even throw in a few of them
# 29                                               My house
# ...                                                   ...
# 304914                                     don't you know
# 304915        Who's got two thumbs and loves woodworking?
# 304916                                 space tribe undies
# 304917  something tells me you guys are not taking me ...
# 304918                                        Psychedelic
# 304919   Yeah bra I'll pay ya set fee from the gate sales
# 304920                        Cops wanna shut down omega?
# 304921                                      one hour sets
# 304922                                   Need Music brus?
# 304923                       had permission by the police
# 304924                                        dj producer
# 304925                                           the real
# 304926                don't go messin' with a country boy
# 304927                                     thomas be like
# 304928
# 304929  We want to present Maitreya Festival as the sh...
# 304930                      Maitreya Festival experiences
# 304931                                            SHAPERZ
# 304932                     When she says be more creative
# 304933                                        Earthdance?
# 304934                                    Best forum ever
# 304935                                          Earthcore
# 304936                                            cluster
# 304937                                          earthcore
# 304938                                  Earthcore paid me
# 304939                                        street team
# 304940                                        Matt florey
# 304941                                 buys a $5000 synth
# 304942  Islamic / Muslim Jihad, Jihadism, Jihadi and J...
# 304943  Salafi islámico / musulmán (salafismo / salafi...
#
#                                             CaptionBottom  \
# 0             I AINT NO HOMO SAPIEN    IM A HETERO SAPIEN
# 1                                           ITS GON BE ME
# 2                                  cousins with benefits?
# 3                        Asked "Can we still be Cousins?"
# 4                                        TO PICK UP WOMEN
# 5                            WHEN YA GOT A PICK-UP TRUCK.
# 6                            only needed to get one thing
# 7                                        is my girlfriend
# 8                             if I'd had better teachers!
# 9                                i love them country boys
# 10                      ...hell, it's good enough for me!
# 11                       ASKED "CAN WE STILL BE COUSINS?"
# 12            that made us spend more money than we have!
# 13                               damn, now i need condoms
# 14       Is because i dont want to hang with all the fags
# 15                                           TOOK'R JEWBS
# 16      it is simply a cultural taboo that was imposed...
# 17           the only math i need to know is 4x4=off road
# 18                                              gets laid
# 19                                           I have a keg
# 20                     I just dress like a ghost everyday
# 21                                            than lebron
# 22                            these creepy floating words
# 23                                 your pig squeels less.
# 24                                  are both in 6th grade
# 25                                       mines bud-wiser!
# 26                                           "Dishwasher"
# 27                                           fuckers fast
# 28                                   Lubricated balloons!
# 29                             has more miles than my car
# ...                                                   ...
# 304914                                          who I am?
# 304915                            This guy...but not you!
# 304916                                              comfy
# 304917                           i forgive you, let's hug
# 304918                                   is a music genre
# 304919   Yeah nah didn't break even wanna buy some drugs?
# 304920                         yeah nah  good luck carnts
# 304921                                            psy lol
# 304922                    cracking chunks set ready to go
# 304923                  but they have changed there minds
# 304924                                             artist
# 304925                                             psylol
# 304926                        a country boy,a country boy
# 304927  ik heb een keer een meisje aangeraakt. ik moes...
# 304928                                           DUIMPIEE
# 304929        TICKETS WILL BE REFUNDED IN THE NEXT 72 HRS
# 304930  have ticked all the boxes have all relevant ap...
# 304931             domenica aperti dalle 15:00 alle 19:00
# 304932                   But you take it to another level
# 304933                           Private INVITE ONLY mate
# 304934                                      two thumbs up
# 304935                              credit card claw back
# 304936                                               fuck
# 304937                                        got my visa
# 304938                                     with an i.o.u.
# 304939                                         5/5 toimii
# 304940                               You are really GAY!!
# 304941                    never uses the fine tuning knob
# 304942  The Embera, Kuna and Ngabe Bugle Guaymi of Panama
# 304943  Los Maya Totanac de Veracruz, San Luis Potosí ...
#
#                                        ImageName Upvotes
# 0       ../data/images/Stereotypical-Redneck.jpg      36
# 1       ../data/images/Stereotypical-Redneck.jpg      28
# 2       ../data/images/Stereotypical-Redneck.jpg      28
# 3       ../data/images/Stereotypical-Redneck.jpg      22
# 4       ../data/images/Stereotypical-Redneck.jpg      15
# 5       ../data/images/Stereotypical-Redneck.jpg      11
# 6       ../data/images/Stereotypical-Redneck.jpg      11
# 7       ../data/images/Stereotypical-Redneck.jpg       8
# 8       ../data/images/Stereotypical-Redneck.jpg       8
# 9       ../data/images/Stereotypical-Redneck.jpg       7
# 10      ../data/images/Stereotypical-Redneck.jpg       5
# 11      ../data/images/Stereotypical-Redneck.jpg       5
# 12      ../data/images/Stereotypical-Redneck.jpg       5
# 13      ../data/images/Stereotypical-Redneck.jpg       4
# 14      ../data/images/Stereotypical-Redneck.jpg       4
# 15      ../data/images/Stereotypical-Redneck.jpg       4
# 16      ../data/images/Stereotypical-Redneck.jpg       4
# 17      ../data/images/Stereotypical-Redneck.jpg       4
# 18      ../data/images/Stereotypical-Redneck.jpg       3
# 19      ../data/images/Stereotypical-Redneck.jpg       3
# 20      ../data/images/Stereotypical-Redneck.jpg       3
# 21      ../data/images/Stereotypical-Redneck.jpg       3
# 22      ../data/images/Stereotypical-Redneck.jpg       3
# 23      ../data/images/Stereotypical-Redneck.jpg       3
# 24      ../data/images/Stereotypical-Redneck.jpg       3
# 25      ../data/images/Stereotypical-Redneck.jpg       3
# 26      ../data/images/Stereotypical-Redneck.jpg       3
# 27      ../data/images/Stereotypical-Redneck.jpg       3
# 28      ../data/images/Stereotypical-Redneck.jpg       3
# 29      ../data/images/Stereotypical-Redneck.jpg       2
# ...                                          ...     ...
# 304914                 ../data/images/Psylol.jpg       0
# 304915                 ../data/images/Psylol.jpg       0
# 304916                 ../data/images/Psylol.jpg       0
# 304917                 ../data/images/Psylol.jpg       0
# 304918                 ../data/images/Psylol.jpg       0
# 304919                 ../data/images/Psylol.jpg       0
# 304920                 ../data/images/Psylol.jpg       0
# 304921                 ../data/images/Psylol.jpg       0
# 304922                 ../data/images/Psylol.jpg       0
# 304923                 ../data/images/Psylol.jpg       0
# 304924                 ../data/images/Psylol.jpg       0
# 304925                 ../data/images/Psylol.jpg       0
# 304926                 ../data/images/Psylol.jpg       0
# 304927                 ../data/images/Psylol.jpg       0
# 304928                 ../data/images/Psylol.jpg       0
# 304929                 ../data/images/Psylol.jpg       0
# 304930                 ../data/images/Psylol.jpg       0
# 304931                 ../data/images/Psylol.jpg       0
# 304932                 ../data/images/Psylol.jpg       0
# 304933                 ../data/images/Psylol.jpg       0
# 304934                 ../data/images/Psylol.jpg       0
# 304935                 ../data/images/Psylol.jpg       0
# 304936                 ../data/images/Psylol.jpg       0
# 304937                 ../data/images/Psylol.jpg       0
# 304938                 ../data/images/Psylol.jpg       0
# 304939                 ../data/images/Psylol.jpg       0
# 304940                 ../data/images/Psylol.jpg       0
# 304941                 ../data/images/Psylol.jpg       0
# 304942                 ../data/images/Psylol.jpg       0
# 304943                 ../data/images/Psylol.jpg       0
#
# [304944 rows x 6 columns]
