# %%
# Initial imports
import numpy as np
import pandas as pd 
from pandas import DataFrame, Series
import matplotlib.pyplot as plt
import seaborn as sns
from scipy import stats
# %matplotlib inline

import random
import urllib.request
import requests
import shutil
from bs4 import BeautifulSoup
import warnings
warnings.filterwarnings('ignore')

# %%
base_url = "https://memegenerator.net/memes/popular/alltime/page/"

columns = ['Title', 'Link', 'Image']
data = DataFrame(columns=columns)

for page in range(1, 201):
    if page % 20 == 0:
        print(page)
    url = base_url + str(page)
    source_code = requests.get(url)
    plain_text = source_code.text
    soup = BeautifulSoup(plain_text)
    img_divs = soup.findAll('div', {'class': 'char-img'})
    for img_div in img_divs:
        img_src = img_div.find('img').get('src')
        link = img_div.find('a').get('href')
        title = img_div.find('div', {'class': 'left'}).text.strip()
        tmp = DataFrame([[title, link, img_src]])
        tmp.columns = columns
        data = data.append(tmp, ignore_index=True)

# %%
data.to_csv('../data/meme_metadata.csv', encoding='utf-8', index=False)

# %%
data = pd.read_csv('../data/meme_metadata.csv')

# %%
# EDIT THESE NUMBERS DEPENDING ON THE MEMES YOU ARE SUPPOSED TO CRAWL
offset = 100
start = 0 + 90 + offset
end = start + 10
data = data[start:end]

# %%
def download_web_image(url, name):
    r = requests.get(url, stream=True, headers={'User-agent': 'Mozilla/5.0'})
    full_name = '../data/images' + str(name) + '.jpg'
    
    if r.status_code == 200:
        with open(full_name, 'wb') as f:
            r.raw.decode_content = True
            shutil.copyfileobj(r.raw, f)
    else:
        print('Could not download ' + str(name))
    return full_name

# %%
columns = ['Title', 'Link', 'CaptionTop', 'CaptionBottom', 'ImageName', 'Upvotes']
caption_data = DataFrame(columns=columns)

for index, row in data.iterrows():
    if index % 500 == 0:
        print(index)
    meme_link = row['Link']
    img_link = row['Image']
    img_name = row['Title']
    download_name = download_web_image(img_link, meme_link)
    base_url = 'https://memegenerator.net'
    page = 1
    flag = True
    for page in range(1, 500):
        url = base_url + row['Link'] + '/images/popular/alltime/page/' + str(page)
        source_code = requests.get(url)
        plain_text = source_code.text
        soup = BeautifulSoup(plain_text)
        for meme in soup.findAll('div', {'class': 'gallery-img'}):
            caption = meme.find('div', {'class': 'optimized-instance-container'})
            text0 = caption.find('div', {'class': 'optimized-instance-text0'}).text.strip()
            text1 = caption.find('div', {'class': 'optimized-instance-text1'}).text.strip()
            upvotes = int(meme.find('div', {'class': 'score'}).text.replace(',', '').strip())
            if upvotes < 0:
                continue
            tmp = DataFrame([[img_name, meme_link, text0, text1, download_name, upvotes]])
            tmp.columns = columns
            caption_data = caption_data.append(tmp, ignore_index=True)

# %%
caption_data.to_csv('../data/caption_data_' + str(start) + '_' + str(end) + '.csv', encoding='utf-8', index=False)

# %%
caption_data
# Out:
#                            Title                       Link  \
# 0       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 1       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 2       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 3       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 4       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 5       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 6       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 7       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 8       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 9       Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 10      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 11      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 12      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 13      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 14      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 15      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 16      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 17      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 18      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 19      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 20      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 21      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 22      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 23      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 24      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 25      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 26      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 27      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 28      Monsieur Le Courage Wolf  /Monsieur-Le-Courage-Wolf
# 111887  i earned my liberal arts degree in a tradition...
# 111888                        in case you're wondering...
# 111889                            by our tribal instincts
# 111890                       When the SBD rate increases,
# 111891  there's two things i hate: those who judge peo...
# 111892         "I feel like",  "I feel that", "I feel---"
# 111893  ISIS Islamic State ISIL/IS Daesh (Daish), Al Q...
# 111894                                       Disingenuous
# 111895  ISIS Islamic State (ISIL / IS) Daesh Terrorist...
# 111896  Blaming muslims for terrorism is wrong. blamin...
# 111897  blaming muslims for terrorism is wrong. blamin...
# 111898  blaming muslims for terrorism is wrong. blamin...
# 111899                                   collects welfare
#
#                                             CaptionBottom  \
# 0                                        becomes new meme
# 1                        exists thanks to us, just sayin'
# 2                                             french army
# 3                                                       V
# 4                                                best not
# 5                                              surrenders
# 6                                       but i am le tired
# 7                                            ONE: REVERSE
# 8                                       is totally busted
# 9                   in case your enemy wants to surrender
# 10                                                bitchez
# 11                                            I just lost
# 12                  consider not surrendering immediately
# 13                                       BETTER SURRENDER
# 14                                           gets flanked
# 15                                   is an injured canvas
# 16                          so germans can march in shade
# 17                                              ... again
# 18                      before i taunt you a  second time
# 19                             but ill shave it for later
# 20                                          5 aRE REVERSE
# 21                              in your general direction
# 22                                       never posts meme
# 23                                              IN FRENCH
# 24                                    has anyone seen zem
# 25         still thinks everybody sees him as the leader.
# 26                                      le ro hoh hoh hoh
# 27                                    france declares war
# 28                          zu not kno how to caption meh
# 29                                                 resist
# ...                                                   ...
# 111870  it's not fair for people to be happy when i'm ...
# 111871                          2024 is not that far away
# 111872                           does it anyway to fit in
# 111873                           to the NFL's new fanbase
# 111874                                                Bot
# 111875                                       Get over it!
# 111876  Loves to make fat jokes at the expense of Dona...
# 111877  Calls Donald trump "a fat cheetoo with doll ha...
# 111878  Makes jokes about "fat" Sarah Elizabeth Huckab...
# 111879           Mocks christianity every chance he gets.
# 111880  sp411 erotic review cerb perb terb merb lyla b...
# 111881  Australian police charge seven people with abu...
# 111882                                        get over it
# 111883                                   said no one ever
# 111884                                          hippy day
# 111885                   she will make you wear her purse
# 111886                                  i look like what?
# 111887                              because i'm a liberal
# 111888  i'm sheldon cooper's stunt double on "big bang...
# 111889    Mankind lived without a straight line in nature
# 111890                       But you do not have any SBD.
# 111891                                   and white people
# 111892  My parents would have given you something to f...
# 111893             The Chorotega and Bribri of Costa Rica
# 111894                                        Lib Bastard
# 111895                  The Bretons of Brittany in France
# 111896  Republicans are to blam for mass shootings. Nr...
# 111897  Republicans are to blame for mass shootings. n...
# 111898  republicans are to blame for mass shootings. n...
# 111899                            lives in mom's basement
#
#                                           ImageName Upvotes
# 0       ../data/images/Monsieur-Le-Courage-Wolf.jpg      55
# 1       ../data/images/Monsieur-Le-Courage-Wolf.jpg      21
# 2       ../data/images/Monsieur-Le-Courage-Wolf.jpg      14
# 3       ../data/images/Monsieur-Le-Courage-Wolf.jpg      13
# 4       ../data/images/Monsieur-Le-Courage-Wolf.jpg      11
# 5       ../data/images/Monsieur-Le-Courage-Wolf.jpg      10
# 6       ../data/images/Monsieur-Le-Courage-Wolf.jpg       9
# 7       ../data/images/Monsieur-Le-Courage-Wolf.jpg       9
# 8       ../data/images/Monsieur-Le-Courage-Wolf.jpg       8
